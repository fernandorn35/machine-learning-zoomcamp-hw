# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.3.1'

# %%
df = pd.read_csv('https://raw.githubusercontent.com/alexeygrigorev/datasets/master/car_fuel_efficiency.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9704 entries, 0 to 9703
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   engine_displacement  9704 non-null   int64
#  1   num_cylinders        9222 non-null   float64
#  2   horsepower           8996 non-null   float64
#  3   vehicle_weight       9704 non-null   float64
#  4   acceleration         8774 non-null   float64
#  5   model_year           9704 non-null   int64
#  6   origin               9704 non-null   object
#  7   fuel_type            9704 non-null   object
#  8   drivetrain           9704 non-null   object
#  9   num_doors            9202 non-null   float64
#  10  fuel_efficiency_mpg  9704 non-null   float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 834.1+ KB

# %%
df
# Out:
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                     170            3.0       159.0     3413.433759
# 1                     130            5.0        97.0     3149.664934
# 2                     170            NaN        78.0     3079.038997
# 3                     220            4.0         NaN     2542.392402
# 4                     210            1.0       140.0     3460.870990
# ...                   ...            ...         ...             ...
# 9699                  140            5.0       164.0     2981.107371
# 9700                  180            NaN       154.0     2439.525729
# 9701                  220            2.0       138.0     2583.471318
# 9702                  230            4.0       177.0     2905.527390
# 9703                  270            3.0       140.0     2908.043477
#
#       acceleration  model_year  origin fuel_type         drivetrain  \
# 0             17.7        2003  Europe  Gasoline    All-wheel drive
# ...

# %%
unique_names = df['fuel_type'].unique()
print(f"Unique names: {unique_names}")
# Out:
# Unique names: ['Gasoline' 'Diesel']

# %%
df.columns[df.isnull().any()]
# Out:
# Index(['num_cylinders', 'horsepower', 'acceleration', 'num_doors'], dtype='object')

# %%
filtered_df = df[df['origin'] == 'Asia']

# %%
filtered_df
# Out:
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 8                     250            1.0       174.0     2714.219310
# 12                    320            5.0       145.0     2783.868974
# 14                    200            6.0       160.0     3582.687368
# 20                    150            3.0       197.0     2231.808142
# 21                    160            4.0       133.0     2659.431451
# ...                   ...            ...         ...             ...
# 9688                  260            4.0         NaN     3948.404625
# 9692                  180            3.0       188.0     3680.341381
# 9693                  280            2.0       148.0     2545.070139
# 9698                  180            1.0       131.0     3107.427820
# 9703                  270            3.0       140.0     2908.043477
#
#       acceleration  model_year origin fuel_type         drivetrain  num_doors  \
# ...

# %%
columns_with_nan = df.isna().any()

print("Columns with NaN values (True if NaN exists):")
print(columns_with_nan)
# Out:
# Columns with NaN values (True if NaN exists):
# engine_displacement    False
# num_cylinders           True
# horsepower              True
# vehicle_weight         False
# acceleration            True
# model_year             False
# origin                 False
# fuel_type              False
# drivetrain             False
# num_doors               True
# fuel_efficiency_mpg    False
# dtype: bool

# %%
max_value_col_a = filtered_df['fuel_efficiency_mpg'].max()

# %%
max_value_col_a
# Out:
# np.float64(23.759122836520497)

# %%
df
# Out:
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                     170            3.0       159.0     3413.433759
# 1                     130            5.0        97.0     3149.664934
# 2                     170            NaN        78.0     3079.038997
# 3                     220            4.0         NaN     2542.392402
# 4                     210            1.0       140.0     3460.870990
# ...                   ...            ...         ...             ...
# 9699                  140            5.0       164.0     2981.107371
# 9700                  180            NaN       154.0     2439.525729
# 9701                  220            2.0       138.0     2583.471318
# 9702                  230            4.0       177.0     2905.527390
# 9703                  270            3.0       140.0     2908.043477
#
#       acceleration  model_year  origin fuel_type         drivetrain  \
# 0             17.7        2003  Europe  Gasoline    All-wheel drive
# ...

# %%
median_horsepower = df['horsepower'].median()

# %%
print(median_horsepower)
# Out:
# 149.0

# %%
most_frequent = df['horsepower'].mode()

# %%
print(most_frequent)
# Out:
# 0    152.0
# Name: horsepower, dtype: float64

# %%
df['horsepower'] = df['horsepower'].fillna(most_frequent)

# %%
median_horsepower = df['horsepower'].median()

# %%
print(median_horsepower)
# Out:
# 149.0

# %% [markdown]
# ### No

# %%
filtered_df_1 = df[df['origin'] == 'Asia']

# %%
filtered_df_1 = filtered_df_1[['vehicle_weight', 'model_year']]

# %%
filtered_df_1
# Out:
#       vehicle_weight  model_year
# 8        2714.219310        2016
# 12       2783.868974        2010
# 14       3582.687368        2007
# 20       2231.808142        2011
# 21       2659.431451        2016
# ...              ...         ...
# 9688     3948.404625        2018
# 9692     3680.341381        2016
# 9693     2545.070139        2012
# 9698     3107.427820        2005
# 9703     2908.043477        2005
#
# [3247 rows x 2 columns]

# %%
filtered_df_1 = filtered_df_1.iloc[0:6]

# %%
filtered_df_1
# Out:
#     vehicle_weight  model_year
# 8      2714.219310        2016
# 12     2783.868974        2010
# 14     3582.687368        2007
# 20     2231.808142        2011
# 21     2659.431451        2016
# 34     2844.227534        2014

# %%
X = filtered_df_1['vehicle_weight'].values

# %%
X
# Out:
# array([2714.21930965, 2783.86897424, 3582.68736772, 2231.8081416 ,
#        2659.43145076, 2844.22753389])
